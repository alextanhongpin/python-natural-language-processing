# %%
import nltk

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))
filename = './data/sherlock_holmes.txt'
file = open(filename, 'r', encoding='utf-8')
text = file.read()
text = text.replace('\n', ' ')
words = nltk.tokenize.word_tokenize(text)
words_without_stopwords = [word for word in words if word not in stopwords]
print(len(words), len(words_without_stopwords))
# Out:
# 125119 74158

# %% [markdown]
# ## Compiling stopwords using FreqDist

# %%
import nltk
from nltk.probability import FreqDist

# %%
file = open(filename, 'r', encoding='utf-8')
text = file.read()

# Remove newlines for better readability.
text = text.replace('\n', ' ')

# Tokenize the text.
words = nltk.tokenize.word_tokenize(text)

# %%
# Create a frequency distribution object and use it to create a tuple,
# where the first element of the tuple is the word, 
# and the second one is the frequency count.
freq_dist = FreqDist(word.lower() for word in words)
words_with_frequencies = [(word, freq_dist[word]) for word in freq_dist.keys()]
sorted_words = sorted(words_with_frequencies, key=lambda tup: tup[1])
print(sorted_words)
# Out:
# [('conan', 1), ('doyle', 1), ('eclipses', 1), ('predominates', 1), ('sex', 1), ('emotions', 1), ('abhorrent', 1), ('balanced', 1), ('softer', 1), ('passions', 1), ('gibe', 1), ('observer—excellent', 1), ('intrusions', 1), ('finely', 1), ('temperament', 1), ('distracting', 1), ('mental', 1), ('grit', 1), ('sensitive', 1), ('instrument', 1), ('high-power', 1), ('lenses', 1), ('disturbing', 1), ('dubious', 1), ('home-centred', 1), ('establishment', 1), ('absorb', 1), ('loathed', 1), ('alternating', 1), ('ambition', 1), ('drowsiness', 1), ('occupied', 1), ('odessa', 1), ('trepoff', 1), ('atkinson', 1), ('brothers', 1), ('trincomalee', 1), ('delicately', 1), ('successfully', 1), ('activity', 1), ('shared', 1), ('readers', 1), ('1888—i', 1), ('well-remembered', 1), ('silhouette', 1), ('clasped', 1), ('drug-created', 1), ('effusive', 1), ('spirit', 1), ('gasogene', 1), ('wedlock', 1), ('intended', 1), ('harness.', 1), ('clumsy', 1), ('careless', 1), ('centuries', 1), ('mess', 1), ('jane', 1), ('incorrigible', 1), ('simplicity', 1), ('shoe', 1), ('firelight', 1), ('crusted', 1), ('malignant', 1), ('boot-slitting', 1), ('slavey', 1), ('smelling', 1), ('iodoform', 1), ('nitrate', 1), ('bulge', 1), ('secreted', 1), ('stethoscope', 1), ('profession.', 1), ('ridiculously', 1), ('distinction', 1), ('frequently.', 1), ('times.', 1), ('seventeen', 1), ('experiences', 1), ('pink-tinted', 1), ('notepaper', 1), ('aloud.', 1), ('undated', 1), ('mask.', 1), ('theorise', 1), ('insensibly', 1), ('begins', 1), ('imitate', 1), ('processes', 1), ('peculiarly', 1), ('stiff.', 1), ('peculiar—that', 1), ('light.', 1), ('texture', 1), ('rather.', 1), ('gesellschaft', 1), ('company.', 1), ('customary', 1), ('co.', 1), ('papier.', 1), ('eg.', 1), ('continental', 1), ('gazetteer.', 1), ('eglow', 1), ('eglonitz—here', 1), ('egria', 1), ('german-speaking', 1), ('country—in', 1), ('carlsbad', 1), ('wallenstein', 1), ('numerous', 1), ('glass-factories', 1), ('paper-mills.', 1), ('triumphant', 1), ('construction', 1), ('sentence—', 1), ('received.', 1), ('frenchman', 1), ('russian', 1), ('uncourteous', 1), ('verbs', 1), ('writes', 1), ('prefers', 1), ('curb', 1), ('beauties', 1), ('boswell', 1), ('client—', 1), ('attention.', 1), ('authoritative', 1), ('hercules', 1), ('richness', 1), ('astrakhan', 1), ('slashed', 1), ('fronts', 1), ('double-breasted', 1), ('brooch', 1), ('calves', 1), ('trimmed', 1), ('tops', 1), ('barbaric', 1), ('opulence', 1), ('cheekbones', 1), ('vizard', 1), ('obstinacy', 1), ('harsh', 1), ('call.', 1), ('kramm', 1), ('binding', 1), ('european', 1), ('history.', 1), ('august', 1), ('employs', 1), ('dryly', 1), ('quench', 1), ('compromise', 1), ('implicates', 1), ('kings', 1), ('apparent', 1), ('depicted', 1), ('reopened', 1), ('desperation', 1), ('wilhelm', 1), ('gottsreich', 1), ('sigismond', 1), ('cassel-felstein', 1), ('_incognito_', 1), ('prague', 1), ('consulting', 1), ('shutting', 1), ('lengthy', 1), ('warsaw', 1), ('adventuress', 1), ('docketing', 1), ('paragraphs', 1), ('concerning', 1), ('furnish', 1), ('biography', 1), ('hebrew', 1), ('rabbi', 1), ('staff-commander', 1), ('deep-sea', 1), ('jersey', 1), ('1858', 1), ('contralto—hum', 1), ('la', 1), ('scala', 1), ('prima', 1), ('donna', 1), ('imperial', 1), ('opera', 1), ('warsaw—yes', 1), ('operatic', 1), ('stage—ha', 1), ('london—quite', 1), ('desirous', 1), ('how—', 1), ('certificates', 1), ('blackmailing', 1), ('authenticity', 1), ('writing.', 1), ('forgery.', 1), ('note-paper.', 1), ('stolen.', 1), ('seal.', 1), ('imitated.', 1), ('indiscretion.', 1), ('mad—insane.', 1), ('compromised', 1), ('seriously.', 1), ('prince', 1), ('failed.', 1), ('sell.', 1), ('burglars', 1), ('diverted', 1), ('luggage', 1), ('result.', 1), ('reproachfully', 1), ('married.', 1), ('clotilde', 1), ('lothman', 1), ('saxe-meningen', 1), ('scandinavia', 1), ('principles', 1), ('lengths', 1), ('go—none.', 1), ('sure.', 1), ('betrothal', 1), ('publicly', 1), ('proclaimed', 1), ('langham', 1), ('kramm.', 1),  ...

# %%
# Two options for stopwords choice
# 1. Take the frequency cutoff, that is if the words appears more than 100 times.
stopwords = [tuple[0] for tuple in sorted_words if tuple[1] > 100]
print('len:', len(stopwords))
print('first 5:', stopwords[:5])
# Out:
# len: 131
# first 5: ['away', 'never', 'good', 'nothing', 'case']

# %%
# 2. Take the n% most frequent words
length_cutoff = int(0.02 * len(sorted_words))
print('length_cutoff:', length_cutoff)
stopwords = [tuple[0] for tuple in sorted_words[-length_cutoff:]]
print('len:', len(stopwords))
print('first 5:', stopwords[:5])
# Out:
# length_cutoff: 181
# len: 181
# first 5: ['make', 'myself', 'night', 'until', 'street']
